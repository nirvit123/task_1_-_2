# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
n = int(input().strip())
if n%2!=0:
    print('Weird')
else:
    if 2<=n<=5:
        print('Not Weird')
    elif 6<=n<=20:
        print('Weird')
    else:
        print('Not Weird')
# Out:
# Not Weird

# %%
a = int(input())
b = int(input())
add=a+b
sub=a-b
product=a*b
print(add)
print(sub)
print(product)
# Out:
# 38
# 30
# 136

# %%
    a = int(input())
    b = int(input())
    int1=a//b
    float1=a/b
    print(int1)
    print(float1)
# Out:
# 0
# 0.6666666666666666

# %%
n = int(input())
for i in range (n):
     print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
def is_leap(year):
    if year%400==0:
        leap=True
    elif year%100==0:
        leap=False
    elif year%4==0:
        leap=True
    else:
        leap=False
    # Write your logic here
    
    return leap

year = int(input())
T_F=is_leap(year)
print(T_F)
# Out:
# False

# %%
n=int(input())
stri=''
if n ==1:
    print('1')
else:
    for i in range(1,n+1):
        stri+=str(i)
print(stri)
# Out:
# 123456
